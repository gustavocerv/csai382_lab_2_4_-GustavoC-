-- %%
-- Steps vs. No-Steps
SELECT step_label, COUNT(*)
FROM labeled_step_test
GROUP BY step_label;

-- Invalid or missing labels
SELECT *
FROM labeled_step_test
WHERE step_label NOT IN ('step', 'no_step')
  OR step_label IS NULL
LIMIT 50;

-- Source label counts
SELECT step_label, COUNT(*)
FROM labeled_step_test
GROUP BY step_label;

-- Invalid source labels
SELECT *
FROM silver.labeled_step_test
WHERE step_label NOT IN ('device', 'step')
   OR step_label IS NULL
LIMIT 50;

/*
Ethical Reflection: 

Automating health data analysis carries significant ethical responsibilities. Practitioners must ensure patient privacy and data security, comply with regulations such as HIPAA, and avoid biases that could impact care or outcomes. Transparency in data processing, informed consent, and responsible use of algorithms are essential to maintain trust and protect individuals. Automation should enhance, not replace, human judgment, and all stakeholders must be vigilant against misuse or unintended consequences.
*/
